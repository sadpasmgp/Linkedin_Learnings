# %% [markdown]
# ## Python statistics essential training - 05_06_bayesian

# %% [markdown]
# Standard imports

# %%
import math

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib
import matplotlib.pyplot as pp

# %%
# %matplotlib inline

# %%
import pymc3 as pm

# %%
n = 100
k = 61

with pm.Model() as coin_context:
    p = pm.Uniform('p',0.40,0.80)
    
    y = pm.Binomial('y',n=n,p=p,observed=k)
    
    trace = pm.sample(10000)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [p]
# Sampling 4 chains, 0 divergences: 100%|█████████████████████████████████████| 42000/42000 [00:26<00:00, 1576.56draws/s]
# The acceptance probability does not match the target. It is 0.49008402158312525, but should be close to 0.8. Try to increase the number of tuning steps.

# %%
pm.summary(trace)
# Out:
#     mean     sd  hpd_3%  hpd_97%  mcse_mean  mcse_sd  ess_mean   ess_sd  \
# p  0.608  0.048   0.516    0.697        0.0      0.0   16996.0  16996.0
#
#    ess_bulk  ess_tail  r_hat
# p   17055.0   24176.0    1.0

# %%
pm.traceplot(trace)
# Out:
# C:\Users\sp\anaconda3\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:36: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   warnings.warn(
# C:\Users\sp\anaconda3\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:36: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   warnings.warn(
# C:\Users\sp\anaconda3\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:36: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   warnings.warn(
# C:\Users\sp\anaconda3\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:36: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   warnings.warn(
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000016A407098E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016A405F8280>]],
#       dtype=object)

# %%
gdata=pd.read_csv('gapminder.csv').query('year == 1985')

# %%
gdata.sort_values('age5_surviving',inplace=True)

# %%
pp.scatter(gdata['age5_surviving'],gdata['babies_per_woman'])

# %%
with pm.Model() as gapminder_context:
    intercept = pm.Uniform('intercept',5,15)
    slope = pm.Uniform('slope',-1,1)
    
    babies = pm.Normal('babies',
                       mu = intercept + slope * (gdata['age5_surviving'] - 65),
                       sd = 1,
                       observed = gdata['babies_per_woman'])
    
    trace = pm.sample(10000)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [slope, intercept]
# Sampling 4 chains, 0 divergences: 100%|█████████████████████████████████████| 42000/42000 [00:38<00:00, 1087.51draws/s]
# The number of effective samples is smaller than 25% for some parameters.

# %%
pm.summary(trace)
# Out:
#              mean     sd  hpd_3%  hpd_97%  mcse_mean  mcse_sd  ess_mean  \
# intercept  10.198  0.286   9.666   10.743      0.004    0.002    6586.0
# slope      -0.219  0.010  -0.238   -0.199      0.000    0.000    6598.0
#
#            ess_sd  ess_bulk  ess_tail  r_hat
# intercept  6586.0    6601.0    7490.0    1.0
# slope      6598.0    6617.0    7595.0    1.0

# %%
pm.traceplot(trace)
# Out:
# C:\Users\sp\anaconda3\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:36: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   warnings.warn(
# C:\Users\sp\anaconda3\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:36: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   warnings.warn(
# C:\Users\sp\anaconda3\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:36: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   warnings.warn(
# C:\Users\sp\anaconda3\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:36: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   warnings.warn(
# C:\Users\sp\anaconda3\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:36: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   warnings.warn(
# C:\Users\sp\anaconda3\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:36: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   warnings.warn(
# C:\Users\sp\anaconda3\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:36: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   warnings.warn(
# C:\Users\sp\anaconda3\lib\site-packages\arviz\plots\backends\matplotlib\distplot.py:36: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   warnings.warn(
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000016A41A4E0A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016A41A2AF10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000016A4197C730>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016A417FDEE0>]],
#       dtype=object)

# %%
babies = trace['intercept'].mean() + trace['slope'].mean() * (gdata['age5_surviving'] - 65)

# %%
pp.scatter(gdata['age5_surviving'],gdata['babies_per_woman'])
pp.plot(gdata['age5_surviving'],babies,'C1')

# %%
pp.scatter(gdata['age5_surviving'],gdata['babies_per_woman'])

for i, intercept, slope in zip(range(100),trace['intercept'][::50],trace['slope'][::50]):
    babies = intercept + slope * (gdata['age5_surviving'] - 65)
    pp.plot(gdata['age5_surviving'],babies,'C1',alpha=0.05)
