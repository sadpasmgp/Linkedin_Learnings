# %%
pip install py-AutoClean
# Out:
# Collecting py-AutoClean
#   Downloading py-AutoClean-1.1.2.tar.gz (10.0 kB)
# Requirement already satisfied: scikit-learn in /opt/anaconda3/lib/python3.9/site-packages (from py-AutoClean) (1.0.2)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.9/site-packages (from py-AutoClean) (1.21.5)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.9/site-packages (from py-AutoClean) (1.4.2)
# Collecting loguru
#   Downloading loguru-0.6.0-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 3.3 MB/s eta 0:00:011
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/anaconda3/lib/python3.9/site-packages (from pandas->py-AutoClean) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.9/site-packages (from pandas->py-AutoClean) (2021.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->py-AutoClean) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->py-AutoClean) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in /opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->py-AutoClean) (1.1.0)
# Requirement already satisfied: scipy>=1.1.0 in /opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->py-AutoClean) (1.7.3)
# Building wheels for collected packages: py-AutoClean
#   Building wheel for py-AutoClean (setup.py) ... done
#   Created wheel for py-AutoClean: filename=py_AutoClean-1.1.2-py3-none-any.whl size=10638 sha256=b5c2ae7ce4299d2b1cbd0df4cac5fbfcaadd8e610d5d2aed662525b3f51b6ef3
#   Stored in directory: /Users/sadpasha1/Library/Caches/pip/wheels/1c/92/a4/90338df600a8ed2d32232d8a355bf1febad8c48e2aca89ab7b
# Successfully built py-AutoClean
# Installing collected packages: loguru, py-AutoClean
# Successfully installed loguru-0.6.0 py-AutoClean-1.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline

titanic = pd.read_csv('../../../titanic.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
from AutoClean import AutoClean
pipeline = AutoClean(titanic)

pipeline.output
# Out:
# AutoClean process completed in 0.317363 seconds
# Logfile saved to: /Users/sadpasha1/SP_DEV/Marcel Classes/Ex_Files_Applied_Machine_Learning/Exercise Files/02_EDA/02_02/Start/autoclean.log
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex    Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.00      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.00      1
# 2                               Heikkinen, Miss. Laina  female  26.00      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.00      1
# 4                             Allen, Mr. William Henry    male  35.00      0
# ..                                                 ...     ...    ...    ...
# 886                              Montvila, Rev. Juozas    male  27.00      0
# 887                       Graham, Miss. Margaret Edith  female  19.00      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  18.54      1
# 889                              Behr, Mr. Karl Howell    male  26.00      0
# 890                                Dooley, Mr. Patrick    male  32.00      0
#
#      Parch            Ticket     Fare Cabin Embarked  Sex_female  Sex_male  \
# 0        0         A/5 21171   7.2500  C128        S           0         1
# 1        0          PC 17599  65.6344   C85        C           1         0
# 2        0  STON/O2. 3101282   7.9250  C128        S           1         0
# 3        0            113803  53.1000  C123        S           1         0
# 4        0            373450   8.0500  C128        S           0         1
# ..     ...               ...      ...   ...      ...         ...       ...
# 886      0            211536  13.0000  C128        S           0         1
# 887      0            112053  30.0000   B42        S           1         0
# 888      0        W./C. 6607  23.4500  C128        S           1         0
# 889      0            111369  30.0000  C148        C           0         1
# 890      0            370376   7.7500  C128        Q           0         1
#
#      Embarked_C  Embarked_Q  Embarked_S
# 0             0           0           1
# 1             1           0           0
# 2             0           0           1
# 3             0           0           1
# 4             0           0           1
# ..          ...         ...         ...
# 886           0           0           1
# 887           0           0           1
# 888           0           0           1
# 889           1           0           0
# 890           0           1           0
#
# [891 rows x 17 columns]

# %%
titanic_autocleaned = pipeline.output
titanic_autocleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    Int64
#  1   Survived     891 non-null    Int64
#  2   Pclass       891 non-null    Int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    Int64
#  7   Parch        891 non-null    Int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    object
#  11  Embarked     891 non-null    object
#  12  Sex_female   891 non-null    Int64
#  13  Sex_male     891 non-null    Int64
#  14  Embarked_C   891 non-null    Int64
#  15  Embarked_Q   891 non-null    Int64
#  16  Embarked_S   891 non-null    Int64
# dtypes: Int64(10), float64(2), object(5)
# memory usage: 127.2+ KB

# %%
import seaborn as sns

# %%
sns.pairplot(titanic_autocleaned)
