# %% [markdown]
# # Chapter 4 - Clustering Models
# ## Segment 1 - K-means method
# ### Setting up for clustering analysis

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

import sklearn
from sklearn.preprocessing import scale
import sklearn.metrics as sm
from sklearn.metrics import confusion_matrix, classification_report

# %%
from sklearn.cluster import KMeans
from mpl_toolkits.mplot3d import Axes3D
from sklearn import datasets

# %%
# %matplotlib inline
plt.figure(figsize=(7,4))

# %%
iris = datasets.load_iris()

X = scale(iris.data)
y = pd.DataFrame(iris.target)
variable_names = iris.feature_names
X[0:10]
# Out:
# array([[-0.90068117,  1.01900435, -1.34022653, -1.3154443 ],
#        [-1.14301691, -0.13197948, -1.34022653, -1.3154443 ],
#        [-1.38535265,  0.32841405, -1.39706395, -1.3154443 ],
#        [-1.50652052,  0.09821729, -1.2833891 , -1.3154443 ],
#        [-1.02184904,  1.24920112, -1.34022653, -1.3154443 ],
#        [-0.53717756,  1.93979142, -1.16971425, -1.05217993],
#        [-1.50652052,  0.78880759, -1.34022653, -1.18381211],
#        [-1.02184904,  0.78880759, -1.2833891 , -1.3154443 ],
#        [-1.74885626, -0.36217625, -1.34022653, -1.3154443 ],
#        [-1.14301691,  0.09821729, -1.2833891 , -1.44707648]])

# %% [markdown]
# ## Building and running your model

# %%
clustering = KMeans(n_clusters=3, random_state=5)

clustering.fit(X)
# Out:
# KMeans(n_clusters=3, random_state=5)

# %% [markdown]
# ## Plotting your model outputs

# %%
iris_df = pd.DataFrame(iris.data)
iris_df.columns = ['Sepal_Length', 'Sepal_Width', 'Petal_Length', 'Petal_Width']
y.columns = ['Targets']

# %%
color_theme = np.array(['darkgray', 'lightsalmon', 'powderblue'])

plt.subplot(1,2,1)

plt.scatter(x=iris_df.Petal_Length, y=iris_df.Petal_Width, c=color_theme[iris.target], s=50)
plt.title('Ground Truth Classification')

plt.subplot(1,2,2)

plt.scatter(x=iris_df.Petal_Length, y=iris_df.Petal_Width, c=color_theme[clustering.labels_], s=50)
plt.title('K-Means Classification')
# Out:
# Text(0.5, 1.0, 'K-Means Classification')

# %%
import seaborn as sns

# %%
sns.scatterplot(x=iris_df.Petal_Length, y=iris_df.Petal_Width, hue=iris.target)
plt.grid()

# %%
import plotly.express as px

# %%
px.scatter(x=iris_df.Petal_Length, y=iris_df.Petal_Width, color=color_theme[iris.target])
# Out:
# <div>                            <div id="29fd0621-076a-451f-920a-a186d0f79a78" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("29fd0621-076a-451f-920a-a186d0f79a78")) {                    Plotly.newPlot(                        "29fd0621-076a-451f-920a-a186d0f79a78",                        [{"hovertemplate": "color=darkgray<br>x=%{x}<br>y=%{y}<extra></extra>", "legendgroup": "darkgray", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "darkgray", "orientation": "v", "showlegend": true, "type": "scatter", "x": [1.4, 1.4, 1.3, 1.5, 1.4, 1.7, 1.4, 1.5, 1.4, 1.5, 1.5, 1.6, 1.4, 1.1, 1.2, 1.5, 1.3, 1.4, 1.7, 1.5, 1.7, 1.5, 1.0, 1.7, 1.9, 1.6, 1.6, 1.5, 1.4, 1.6, 1.6, 1.5, 1.5, 1.4, 1.5, 1.2, 1.3, 1.4, 1.3, 1.5, 1.3, 1.3, 1.3
# ...

# %%
px.scatter(x=iris_df.Petal_Length, y=iris_df.Petal_Width, color=color_theme[clustering.labels_])
# Out:
# <div>                            <div id="69a89f53-98a3-43f0-91b4-53a32a2d8eed" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("69a89f53-98a3-43f0-91b4-53a32a2d8eed")) {                    Plotly.newPlot(                        "69a89f53-98a3-43f0-91b4-53a32a2d8eed",                        [{"hovertemplate": "color=lightsalmon<br>x=%{x}<br>y=%{y}<extra></extra>", "legendgroup": "lightsalmon", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "lightsalmon", "orientation": "v", "showlegend": true, "type": "scatter", "x": [1.4, 1.4, 1.3, 1.5, 1.4, 1.7, 1.4, 1.5, 1.4, 1.5, 1.5, 1.6, 1.4, 1.1, 1.2, 1.5, 1.3, 1.4, 1.7, 1.5, 1.7, 1.5, 1.0, 1.7, 1.9, 1.6, 1.6, 1.5, 1.4, 1.6, 1.6, 1.5, 1.5, 1.4, 1.5, 1.2, 1.3, 1.4, 1.3, 1.5, 1.3,
# ...

# %%
relabel = np.choose(clustering.labels_, [2, 0, 1]).astype(np.int64)

plt.subplot(1,2,1)

plt.scatter(x=iris_df.Petal_Length, y=iris_df.Petal_Width, c=color_theme[iris.target], s=50)
plt.title('Ground Truth Classification')

plt.subplot(1,2,2)

plt.scatter(x=iris_df.Petal_Length, y=iris_df.Petal_Width, c=color_theme[relabel], s=50)
plt.title('K-Means Classification')
# Out:
# Text(0.5, 1.0, 'K-Means Classification')

# %% [markdown]
# ## Evaluate your clustering results

# %%
print(classification_report(y, relabel))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        50
#            1       0.23      0.22      0.23        50
#            2       0.26      0.28      0.27        50
#
#     accuracy                           0.50       150
#    macro avg       0.50      0.50      0.50       150
# weighted avg       0.50      0.50      0.50       150
